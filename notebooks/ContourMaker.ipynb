# %%
from ThermoPyle import *
from typing import *
import matplotlib
import matplotlib.cm as cm
import matplotlib.mlab as mlab
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, mpld3
from random import randint

# %matplotlib notebook
mpld3.enable_notebook()

# %%
Water = ThermoFluid(fluid="Water", numPoints =[217,217], xvar="P",yvar="T", zvar="U")

# %%
newCols = ["S", "D", "G"]
for col in newCols:
    try:
        Water.add_column(col)
    except:
        pass

# %%
fluid_contour_plot(Water, Water.zvar)
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
