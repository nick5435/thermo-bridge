# %%
from ThermoPyle import *
import ThermoPyle as TP
import matplotlib
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt, mpld3
from matplotlib import mlab

# %matplotlib notebook
mpld3.enable_notebook()

# %%
Water = CSVFluid("../finalData/Water_T-217_P-217_U_with_ders_and_enthalpy")

# %%
newCols = ["S", "D", "G"]
dercols = ...
for col in newCols:
    try:
        Water.add_column(col)
    except:
        pass

# %%
fluid_contour_plot(Water, xvar="D", yvar="S", contour="U")
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">

# %%
Water.add_column("PHASE")

# %%
fluid_plot(Water, xvar="T", yvar="P", zvar="U", coloring="PHASE")
# Out:
# <img src="data:image/png;base64,..." width="639.999974568686">
